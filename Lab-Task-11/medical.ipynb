# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
dataset = pd.read_csv("medical_insurance.csv")
print(dataset)
# Out:
#       age     sex  bmi  children smoker     region  charges
# 0      19  female   27         0    yes  southwest    16884
# 1      18    male   33         1     no  southeast     1725
# 2      28    male   33         3     no  southeast     4449
# 3      33    male   22         0     no  northwest    13316
# 4      32    male   28         0     no  northwest     3866
# ...   ...     ...  ...       ...    ...        ...      ...
# 2767   47  female   45         1     no  southeast     8569
# 2768   21  female   34         0     no  southwest     2020
# 2769   19    male   26         1    yes  northwest    16450
# 2770   23    male   18         0     no  northwest    21595
# 2771   54    male   31         0     no  southwest     9850
#
# [2772 rows x 7 columns]

# %%
dataset.head()
# Out:
#    age     sex  bmi  children smoker     region  charges
# 0   19  female   27         0    yes  southwest    16884
# 1   18    male   33         1     no  southeast     1725
# 2   28    male   33         3     no  southeast     4449
# 3   33    male   22         0     no  northwest    13316
# 4   32    male   28         0     no  northwest     3866

# %%
dataset.tail()
# Out:
#       age     sex  bmi  children smoker     region  charges
# 2767   47  female   45         1     no  southeast     8569
# 2768   21  female   34         0     no  southwest     2020
# 2769   19    male   26         1    yes  northwest    16450
# 2770   23    male   18         0     no  northwest    21595
# 2771   54    male   31         0     no  southwest     9850

# %%
print('rows: ', dataset.shape[0])
print('columns: ', dataset.shape[1])
# Out:
# rows:  2772
# columns:  7

# %%
dataset.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 2767  False  False  False     False   False   False    False
# 2768  False  False  False     False   False   False    False
# 2769  False  False  False     False   False   False    False
# 2770  False  False  False     False   False   False    False
# 2771  False  False  False     False   False   False    False
#
# [2772 rows x 7 columns]

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
dataset.dtypes
# Out:
# age         int64
# sex           str
# bmi         int64
# children    int64
# smoker        str
# region        str
# charges     int64
# dtype: object

# %%
print(dataset.columns)
for i in dataset.columns:
    print(i)
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')
# age
# sex
# bmi
# children
# smoker
# region
# charges

# %%
dataset.count()
# Out:
# age         2772
# sex         2772
# bmi         2772
# children    2772
# smoker      2772
# region      2772
# charges     2772
# dtype: int64

# %%
dataset.describe()
# Out:
#                age          bmi     children       charges
# count  2772.000000  2772.000000  2772.000000   2772.000000
# mean     39.109668    30.202381     1.086219  13315.885281
# std      14.081459     6.045642     1.123611  11993.749218
# min      18.000000    15.000000     0.000000   1121.000000
# 25%      26.000000    26.000000     0.000000   4827.000000
# 50%      39.000000    30.000000     1.000000   9715.000000
# 75%      51.000000    34.000000     2.000000  15888.250000
# max      64.000000    53.000000     5.000000  63770.000000

# %%
#Data Pre-Processing
dataset.shape
# Out:
# (2772, 7)

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   str
#  2   bmi       2772 non-null   int64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   str
#  5   region    2772 non-null   str
#  6   charges   2772 non-null   int64
# dtypes: int64(4), str(3)
# memory usage: 195.5 KB

# %%
dataset['bmi'] = dataset['bmi'].fillna(dataset['bmi'].mean())

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
def fillnaMean(col):
    for i in col:
        dataset[i] = dataset[i].fillna(dataset[i].mean())

columns = ['bmi', 'children', 'charges']
fillnaMean(columns)

# %%
dataset['children'] = dataset['children'].astype(int) 
dataset['charges'] = dataset['charges'].astype(int) 
dataset['bmi'] = dataset['bmi'].astype(int)

# %%
dataset.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
dataset.to_csv('medical_insurance.csv', index=False, header=True)

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   str
#  2   bmi       2772 non-null   int64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   str
#  5   region    2772 non-null   str
#  6   charges   2772 non-null   int64
# dtypes: int64(4), str(3)
# memory usage: 195.5 KB

# %%
# Train test Split

# %%
data = pd.read_csv('medical_insurance.csv')

# %%
data.head()
# Out:
#    age     sex  bmi  children smoker     region  charges
# 0   19  female   27         0    yes  southwest    16884
# 1   18    male   33         1     no  southeast     1725
# 2   28    male   33         3     no  southeast     4449
# 3   33    male   22         0     no  northwest    13316
# 4   32    male   28         0     no  northwest     3866

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='str')

# %%
X = data.drop('charges', axis=1)
y = data['charges']

# %%
# Encode categorical columns
le = LabelEncoder()
X['sex'] = le.fit_transform(X['sex'])
X['smoker'] = le.fit_transform(X['smoker'])
X['region'] = le.fit_transform(X['region'])

# %%
poly = PolynomialFeatures(degree=2)
X = poly.fit_transform(X)

# %%
X.head()
# Out:
#    age  sex  bmi  children  smoker  region
# 0   19    0   27         0       1       3
# 1   18    1   33         1       0       2
# 2   28    1   33         3       0       2
# 3   33    1   22         0       0       1
# 4   32    1   28         0       0       1

# %%
y.head()
# Out:
# 0    16884
# 1     1725
# 2     4449
# 3    13316
# 4     3866
# Name: charges, dtype: int64

# %%
train_X, test_X, train_y, test_y = train_test_split(X,y, test_size=0.2, shuffle=False)

# %%
print(train_X.shape, train_y.shape)
print(test_X.shape, test_y.shape)
# Out:
# (2217, 6) (2217,)
# (555, 6) (555,)

# %%
print("Total:", len(X))
print("Train:", len(train_X))
print("Test:", len(test_X))
# Out:
# Total: 2772
# Train: 2217
# Test: 555

# %%
# Apply Model

# %%
model = LinearRegression()

# %%
model.fit(train_X, train_y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(test_X)
print("Predictions:", predictions)
# Out:
# Predictions: [ 5794.41751032  4204.01054365 14111.43443254  8812.98128595
#  11088.56389354  6898.86031324 12126.75669386  6335.14816366
#  13446.27902685  3146.15226053 11578.6402164  28607.75269485
#  35121.42931201 11975.26616435 36820.82550707 12155.745118
#  10557.60309047  2466.76009304 12728.32309899 31193.85116072
#  15273.01337119 35026.90029987 10838.39782691 33547.43414903
#   2296.92064264 34134.94392641 25880.58304546  5398.35529903
#  11203.79700251 36474.67927123  8049.29602107 14121.73365359
#   4276.58220335  8753.85919691  8310.61978874  4673.19368109
#  16469.87345067 11762.71642859  3531.80959603 11982.81213663
#   4699.68125136  6565.82336585  8855.64273522  8442.48815586
#   3490.92511582  9441.39001376  9769.77991559  7722.71193852
#   7593.59682017  5910.59795858  3662.9251379   1472.72873516
#  38475.78328381  5412.41192678 29038.91591291 35531.37353267
#   7375.84181785  5926.61168942 14066.77255975 36303.7123475
#   8766.89719652 10327.73753216 36476.27610624 14859.46071899
#  17298.59557598 30575.69281786  2029.6332675   5655.56690759
#    592.4937994   8444.26512491 39317.58575715  5836.94766164
#  12112.50546185 14201.85128557  5981.23250107  7668.55250602
#  10151.78549913 17749.42427685 26905.61772123  3729.02946256
#  26723.18718015 13430.265296    8190.48732953  5737.67944742
#   4942.65609813 31049.9210737  30631.49792147 12238.03779188
#   8532.73039052 11539.36374421 14069.64263626  7921.02491249
#   8423.38640971  6119.84517912 12900.90132795  1192.63798788
#   9228.840278   16347.22566737 10000.29496963 10043.00525499
#   8521.00895282 10111.97414048 10449.14323286  9219.32824808
#  11421.39185668 10450.96352234  8837.69188717  2237.66725565
#  10899.2335787    245.20562001 16080.8567813   6415.31463173
#    558.97515742 16313.70702539 13722.93266375 10708.69003147
